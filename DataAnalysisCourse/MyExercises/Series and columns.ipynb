# %%
#https://infobip.udemy.com/course/python-data-analysis-visualization/learn/lecture/29489280#overview
#https://pandas.pydata.org/docs/reference/series.html
#https://pandas.pydata.org/docs/reference/api/pandas.Series.plot.html#pandas.Series.plot

import pandas as pd
houses = pd.read_csv("Downloads/DataAnalysisCourseMaterials (1)/DataAnalysis/data/kc_house_data.csv")
titanic = pd.read_csv("Downloads/DataAnalysisCourseMaterials (1)/DataAnalysis/data/titanic.csv")
netflix = pd.read_csv("Downloads/DataAnalysisCourseMaterials (1)/DataAnalysis/data/netflix_titles.csv", sep="|", index_col=0)
books = pd.read_csv("Downloads/DataAnalysisCourseMaterials (1)/DataAnalysis/data/bestsellers.csv")

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#oba isti rezultat daju ali bolje je koristiti ovaj ispod za selektiranje kolona, ovaj s točkom je jednostavnije koristiti ali je ograničen (npr ako u nazivu postoji razmak ili točka u nazivu)
titanic.name
titanic['name']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic['name']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic.age
# Out:
# 0           29
# 1       0.9167
# 2            2
# 3           30
# 4           25
#          ...
# 1304      14.5
# 1305         ?
# 1306      26.5
# 1307        27
# 1308        29
# Name: age, Length: 1309, dtype: object

# %%
mystery_col = "price"
houses[mystery_col]
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#series je datastructure
#jednodimenzionalna lista

names = titanic.name
type(names)
# Out:
# pandas.core.series.Series

# %%
names
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
type(houses.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 type(houses.mean())
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...

# %%
houses.sum()

# %%
houses.price.sum()

# %%
houses.price.max()

# %%
names.shape

# %%
titanic.shape

# %%
names.values

# %%
mins = houses.min(numeric_only=True)

# %%
mins

# %%
netflix.title

# %%
netflix.title.tail(50)

# %%
houses.describe

# %%
houses["price"].describe()

# %%
netflix["rating"].describe()

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix.release_year.describe()
# Out:
# count    8807.000000
# mean     2014.180198
# std         8.819312
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
titanic.name
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %% [markdown]
# # unique, nunique

# %%
#unique vrijednosti za column bedrooms

houses["bedrooms"].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#unique vrijednosti za column rating, nan je missing value
netflix.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
#koliko je jedinsvaenih vrijednosti, ne zbraja missing value pod jednostvenu vrijednost

netflix.rating.nunique()
# Out:
# 17

# %%
houses.zipcode.unique()
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039], dtype=int64)

# %%
#koliko unique vrijednosti u koloni

houses.zipcode.nunique()
# Out:
# 70

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
#koliko je jedinsvaenih vrijednosti, uz dropna će zbrojiti i missing value

netflix.rating.nunique(dropna=False)
# Out:
# 18

# %% [markdown]
#  # nlargest, nsmallest

# %%
#daj mi 5 najvećih iz kolone price
houses.price.nlargest()
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# Name: price, dtype: float64

# %%
#daj mi 9 najvećih iz kolone price
houses.price.nlargest(9)
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# 1315    5300000.0
# 1164    5110800.0
# 8092    4668000.0
# 2626    4500000.0
# Name: price, dtype: float64

# %%
houses.price.nsmallest(10)
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# 2141     82500.0
# 18468    83000.0
# 3767     84000.0
# 10253    85000.0
# 16714    85000.0
# Name: price, dtype: float64

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.pclass.nlargest(5)
# Out:
# 600    3
# 601    3
# 602    3
# 603    3
# 604    3
# Name: pclass, dtype: int64

# %%
titanic.pclass.nlargest(5, keep="all")
# Out:
# 600     3
# 601     3
# 602     3
# 603     3
# 604     3
#        ..
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 709, dtype: int64

# %%
#10 najvećih rangiranih prema cijeni

houses.nlargest(10, ["price"])
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
#10 najvećih rangiranih prema bedrooms

houses.nlargest(10, ["bedrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
#10 najvećih rangiranih prema bedrooms primarno, pa zatim prema bathrooms jer imam više bedrooms-a sa istim brojem
houses.nlargest(10, ["bedrooms", "bathrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses.nsmallest(10, ["sqft_lot"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15743  9828702895  20141022T000000   700000.0         4       1.75
# 5826   1773101159  20150107T000000   250000.0         3       2.25
# 7589   6371000026  20150122T000000   367500.0         2       2.00
# 3452   2559950110  20150422T000000  1234570.0         2       2.50
# 20604  7899800857  20141215T000000   256950.0         2       2.00
# 21552   688000017  20140627T000000   516500.0         1       1.25
# 547    7899800860  20150319T000000   259950.0         2       2.00
# 4352   7899800864  20150305T000000   259950.0         2       2.00
# 19662  3362400125  20150303T000000   405000.0         3       2.00
# 21519  1702901618  20150407T000000   420000.0         1       2.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15743         2420       520     1.5           0     0  ...      7
# 5826          1050       572     2.0           0     0  ...      7
# ...

# %% [markdown]
# # select mutiple columns

# %%
#dobili smo series koji sadrže sve direktore/vrijednosti iz kolone direktori

netflix.director
# Out:
# 0       Kirsten Johnson
# 1                   NaN
# 2       Julien Leclercq
# 3                   NaN
# 4                   NaN
#              ...
# 8802      David Fincher
# 8803                NaN
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
#nested lista koja vraća dataframe (znam da je dataframe po tome što piše koliko kolona i redova), series nema kolone i redove nego je single dimension
netflix[["title"]]
# Out:
#                       title
# 0      Dick Johnson Is Dead
# 1             Blood & Water
# 2                 Ganglands
# 3     Jailbirds New Orleans
# 4              Kota Factory
# ...                     ...
# 8802                 Zodiac
# 8803            Zombie Dumb
# 8804             Zombieland
# 8805                   Zoom
# 8806                 Zubaan
#
# [8807 rows x 1 columns]

# %%
netflix[["title", "rating"]].tail(10)
# Out:
#                    title rating
# 8797           Zak Storm  TV-Y7
# 8798            Zed Plus  TV-MA
# 8799               Zenda  TV-14
# 8800  Zindagi Gulzar Hai  TV-PG
# 8801             Zinzana  TV-MA
# 8802              Zodiac      R
# 8803         Zombie Dumb  TV-Y7
# 8804          Zombieland      R
# 8805                Zoom     PG
# 8806              Zubaan  TV-14

# %%
#i uz describe dobijem basic numerički status te tri kolone 
houses[["price", "bedrooms", "bathrooms"]].describe()
# Out:
#               price      bedrooms     bathrooms
# count  2.161300e+04  21613.000000  21613.000000
# mean   5.400881e+05      3.370842      2.114757
# std    3.671272e+05      0.930062      0.770163
# min    7.500000e+04      0.000000      0.000000
# 25%    3.219500e+05      3.000000      1.750000
# 50%    4.500000e+05      3.000000      2.250000
# 75%    6.450000e+05      4.000000      2.500000
# max    7.700000e+06     33.000000      8.000000

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
cols = ["price", "zipcode", "sqft_lot"]
houses[cols]
# Out:
#           price  zipcode  sqft_lot
# 0      221900.0    98178      5650
# 1      538000.0    98125      7242
# 2      180000.0    98028     10000
# 3      604000.0    98136      5000
# 4      510000.0    98074      8080
# ...         ...      ...       ...
# 21608  360000.0    98103      1131
# 21609  400000.0    98146      5813
# 21610  402101.0    98144      1350
# 21611  400000.0    98027      2388
# 21612  325000.0    98144      1076
#
# [21613 rows x 3 columns]

# %% [markdown]
# # value_counts() metoda

# %%
houses["bedrooms"]
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
houses["bedrooms"].value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
titanic.sex.value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
netflix.director.value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
netflix.director.value_counts(ascending=True).head(10)
# Out:
# director
# Kirsten Johnson                  1
# Evgeny Afineevsky                1
# Kristina Goolsby, Ashley York    1
# Phil Joanou                      1
# Anthony Pierce                   1
# Jennifer Phang                   1
# Jill Bauer, Ronna Gradus         1
# Mike Fleiss                      1
# Aziz Ansari                      1
# David Sampliner                  1
# Name: count, dtype: int64

# %%
netflix.director.value_counts(ascending=True)
# Out:
# director
# Kirsten Johnson                   1
# Evgeny Afineevsky                 1
# Kristina Goolsby, Ashley York     1
# Phil Joanou                       1
# Anthony Pierce                    1
#                                  ..
# Jay Karas                        14
# Suhas Kadav                      16
# Marcus Raboy                     16
# Raúl Campos, Jan Suter           18
# Rajiv Chilaka                    19
# Name: count, Length: 4528, dtype: int64

# %%
houses["floors"].value_counts()
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
houses[["bedrooms", "bathrooms"]]
# Out:
#        bedrooms  bathrooms
# 0             3       1.00
# 1             3       2.25
# 2             2       1.00
# 3             4       3.00
# 4             3       2.00
# ...         ...        ...
# 21608         3       2.50
# 21609         4       2.50
# 21610         2       0.75
# 21611         3       2.50
# 21612         2       0.75
#
# [21613 rows x 2 columns]

# %%
prikazuje vrijedosti iz kolona i koliko puta se prikazalo

houses[["bedrooms", "bathrooms"]].value_counts()
# Out:
# bedrooms  bathrooms
# 4         2.50         2502
# 3         2.50         2357
#           1.75         1870
#           1.00         1780
# 2         1.00         1558
#                        ...
# 7         1.00            1
#           3.25            1
#           5.50            1
#           5.75            1
# 33        1.75            1
# Name: count, Length: 144, dtype: int64

# %% [markdown]
# # plot()

# %%
houses.bedrooms
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
#default je line plot, values against labels
houses.bedrooms.plot()
# Out:
# <Axes: >

# %%
houses.bedrooms.value_counts().plot()
# Out:
# <Axes: xlabel='bedrooms'>

# %%
#odabireno vrstu plota
houses.bedrooms.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='bedrooms'>

# %%
#odabireno vrstu plota
houses.bedrooms.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
titanic.survived.value_counts()
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %%
titanic.survived.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
titanic.sex.value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
titanic.sex.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
#uzeo je svaku kolonu
houses.plot()
# Out:
# <Axes: >

# %%
houses[["price", "bedrooms"]].plot()
# Out:
# <Axes: >

# %%
houses[["bedrooms", "bathrooms"]].plot()
# Out:
# <Axes: >

# %%
#samo za dataframe, definiram šta je u x, a što je u y
df = houses[["bedrooms", "bathrooms"]]
df.plot(kind = "scatter", x = "bedrooms", y = "bathrooms")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %%
netflix.rating.value_counts().head(10)
# Out:
# rating
# TV-MA    3207
# TV-14    2160
# TV-PG     863
# R         799
# PG-13     490
# TV-Y7     334
# TV-Y      307
# PG        287
# TV-G      220
# NR         80
# Name: count, dtype: int64

# %%
netflix.rating.value_counts().head(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
# # Series & Plotting

# %%
books["Name"]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
books["Author"].head(8)
# Out:
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# 5         George R. R. Martin
# 6         George R. R. Martin
# 7                 Amor Towles
# Name: Author, dtype: object

# %%
books["Genre"].unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %%
books["Author"].unique()
# Out:
# array(['JJ Smith', 'Stephen King', 'Jordan B. Peterson', 'George Orwell',
#        'National Geographic Kids', 'George R. R. Martin', 'Amor Towles',
#        'James Comey', 'Fredrik Backman', 'Larry Schweikart',
#        'Jaycee Dugard', "Madeleine L'Engle", 'Steve Harvey',
#        'Adult Coloring Book Designs', 'Blue Star Coloring',
#        'Coloring Books for Adults', 'Ron Chernow', 'Anthony Doerr',
#        'Veronica Roth', 'Chris Kyle', 'Khaled Hosseini', 'Glenn Beck',
#        'Neil deGrasse Tyson', 'Mark Twain', 'DK', 'Angie Grace',
#        'Ina Garten', 'Michelle Obama', 'Atul Gawande', 'Ta-Nehisi Coates',
#        'Bruce Springsteen', 'Stephenie Meyer', 'Bill Martin Jr.',
#        'Jeff Kinney', "Sasha O'Hara", 'David Goggins', 'Thomas Piketty',
#        'Suzanne Collins', 'Chrissy Teigen', 'Francis Chan', 'Kevin Kwan',
#        'Marjorie Sarnat', 'Abraham Verghese', 'Brené Brown',
#        'Malcolm Gladwell', 'Charlaine Harris', 'Rod Campbell',
# ...

# %%
books["Author"].nunique()
# Out:
# 248

# %%
#average book price
books["Price"].mean()
# Out:
# 13.1

# %%
#10 s najvišom cijenom
books["Price"].nlargest(10)
# Out:
# 69     105
# 70     105
# 473     82
# 151     54
# 346     53
# 159     52
# 271     46
# 272     46
# 273     46
# 274     46
# Name: Price, dtype: int64

# %%
#3 most comon name

books["Name"].value_counts().head(3)
# Out:
# Name
# Publication Manual of the American Psychological Association, 6th Edition    10
# StrengthsFinder 2.0                                                           9
# Oh, the Places You'll Go!                                                     8
# Name: count, dtype: int64

# %%
books[["Author", "User Rating"]]
# Out:
#                        Author  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ..                        ...          ...
# 545               Jeff Kinney          4.9
# 546               Jen Sincero          4.7
# 547               Jen Sincero          4.7
# 548               Jen Sincero          4.7
# 549               Jen Sincero          4.7
#
# [550 rows x 2 columns]

# %%
books[["Author", "User Rating"]].value_counts()
# Out:
# Author                              User Rating
# Jeff Kinney                         4.8            10
# American Psychological Association  4.5            10
# Gallup                              4.0             9
# Rick Riordan                        4.8             9
# Dr. Seuss                           4.9             8
#                                                    ..
# Ken Follett                         4.5             1
# Kevin Kwan                          4.3             1
# Khaled Hosseini                     4.3             1
# DK                                  4.5             1
# Jeff Kinney                         4.9             1
# Name: count, Length: 301, dtype: int64

# %%
books["Genre"].value_counts()
# Out:
# Genre
# Non Fiction    310
# Fiction        240
# Name: count, dtype: int64

# %%
books["Genre"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
books["Author"].value_counts().head(10)
# Out:
# Author
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
# Dr. Seuss                              9
# Gallup                                 9
# Rob Elliott                            8
# Stephen R. Covey                       7
# Stephenie Meyer                        7
# Name: count, dtype: int64

# %%
books["Author"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Author'>

# %%
#barh jer je lakši za čitati

books["Author"].value_counts().head(10).plot(kind="barh")
# Out:
# <Axes: ylabel='Author'>

# %%
books["User Rating"]
# Out:
# 0      4.7
# 1      4.6
# 2      4.7
# 3      4.7
# 4      4.8
#       ...
# 545    4.9
# 546    4.7
# 547    4.7
# 548    4.7
# 549    4.7
# Name: User Rating, Length: 550, dtype: float64

# %%
books["User Rating"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>
